# %%
#IMPORT THE LIBRARIES
import pandas as pd
import numpy as np

import os
import sys
import tensorflow as tf

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# to play the audio files
import IPython.display as ipd
from IPython.display import Audio

import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM,BatchNormalization
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore"
                         )
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def training_plot(history, epoch, plot_name):
    epochs = [i for i in range(epoch)]
    fig , ax = plt.subplots(1,2)
    train_acc = history.history['accuracy']
    train_loss = history.history['loss']
    test_acc = history.history['val_accuracy']
    test_loss = history.history['val_loss']
    
    fig.set_size_inches(20,6)
    ax[0].plot(epochs , train_loss , label = 'Training Loss')
    ax[0].plot(epochs , test_loss , label = 'Testing Loss')
    ax[0].set_title(f'Training & Testing Loss: {plot_name}')
    ax[0].legend()
    ax[0].set_xlabel("Epochs")
    
    ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
    ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
    ax[1].set_title(f'Training & Testing Accuracy: {plot_name}')
    ax[1].legend()
    ax[1].set_xlabel("Epochs")
    
    plt.savefig(f'Training & Testing Accuracy: {plot_name}.png', dpi=300)
    plt.show()

# %%
# Data = "/kaggle/input/subescobangla-speech-emotion-dataset/SUBESCO"

# %%
Features = pd.read_csv("/kaggle/input/subesco-features/features.csv")

# %%
Features.head()
# Out:
#             0          1          2          3         4         5          6  \
# 0 -296.230011  38.119564 -13.094496   9.386072 -5.185539 -1.639019 -24.183292
# 1 -294.331106  38.511047 -13.068908   9.291030 -4.891412 -1.578612 -24.080665
# 2 -343.421356  36.906116 -15.084600   5.759035 -7.261698 -5.592120 -24.830006
# 3 -196.632034  58.477219   9.385975  18.129421  7.795554 -5.037599  -7.977711
# 4 -134.596416  39.062285  13.661172  13.818711  7.279167 -4.264779  -5.559757
#
#           7          8         9  ...        11         12        13  \
# 0 -0.357210 -23.233494  0.508763  ... -1.771268  -0.732451 -2.919358
# 1 -0.513611 -23.064030  0.513141  ... -1.921915  -0.734482 -3.032744
# 2 -1.729747 -24.118122  3.991151  ...  0.261546  -2.357247 -2.578123
# 3  5.474336 -14.872284 -5.131343  ... -0.465671 -14.692730  2.849876
# 4  1.250663 -10.795258 -8.491890  ... -5.065684  -9.784895 -1.347198
#
#          14        15        16        17        18        19  labels
# 0 -1.677924 -3.435302 -9.161626  2.760259 -2.452390  4.650526    FEAR
# 1 -1.649717 -3.451801 -9.120968  2.602730 -2.513126  4.597749    FEAR
# 2 -1.932598 -5.909747 -7.056637  4.780801 -0.086174  7.494348    FEAR
# 3 -7.054514 -6.213473 -3.276767  0.592177 -4.988083  6.971319    FEAR
# 4 -4.601282 -6.028548 -2.479442 -0.479972 -1.952578  3.902204    FEAR
#
# [5 rows x 21 columns]

# %%
Features
# Out:
#                 0          1          2          3         4         5  \
# 0     -296.230011  38.119564 -13.094496   9.386072 -5.185539 -1.639019
# 1     -294.331106  38.511047 -13.068908   9.291030 -4.891412 -1.578612
# 2     -343.421356  36.906116 -15.084600   5.759035 -7.261698 -5.592120
# 3     -196.632034  58.477219   9.385975  18.129421  7.795554 -5.037599
# 4     -134.596416  39.062285  13.661172  13.818711  7.279167 -4.264779
# ...           ...        ...        ...        ...       ...       ...
# 20995 -147.915032  35.312209  -6.290578   8.826300 -1.185107 -1.087470
# 20996 -279.854645  62.046352 -11.338968  15.105037 -6.672193  1.285805
# 20997 -183.201843  54.706821   3.693384  16.859709  0.532207  1.059522
# 20998 -100.381958  41.417833   8.197202  10.640884  2.796847 -1.045510
# 20999 -236.028137  55.347431   3.616604  16.496374 -0.726685 -0.580750
#
#                6         7          8         9  ...        11         12  \
# 0     -24.183292 -0.357210 -23.233494  0.508763  ... -1.771268  -0.732451
# 1     -24.080665 -0.513611 -23.064030  0.513141  ... -1.921915  -0.734482
# 2     -24.830006 -1.729747 -24.118122  3.991151  ...  0.261546  -2.357247
# 3      -7.977711  5.474336 -14.872284 -5.131343  ... -0.465671 -14.692730
# 4      -5.559757  1.250663 -10.795258 -8.491890  ... -5.065684  -9.784895
# ...          ...       ...        ...       ...  ...       ...        ...
# 20995  -7.562760 -0.137674  -1.489993  1.201304  ... -2.170095  -6.827629
# 20996 -12.235703  4.287932  -3.291110  4.699277  ...  0.055803  -9.658722
# 20997 -11.227297 -0.826561 -12.857935  0.725828  ... -1.448650  -9.543724
# 20998  -6.037356 -4.348273  -8.323692 -3.680360  ... -4.914932  -5.864114
# 20999 -12.464178 -2.115311 -13.284043 -0.442617  ... -0.915420 -12.053455
#
#              13        14        15        16        17        18        19  \
# 0     -2.919358 -1.677924 -3.435302 -9.161626  2.760259 -2.452390  4.650526
# 1     -3.032744 -1.649717 -3.451801 -9.120968  2.602730 -2.513126  4.597749
# 2     -2.578123 -1.932598 -5.909747 -7.056637  4.780801 -0.086174  7.494348
# 3      2.849876 -7.054514 -6.213473 -3.276767  0.592177 -4.988083  6.971319
# 4     -1.347198 -4.601282 -6.028548 -2.479442 -0.479972 -1.952578  3.902204
# ...         ...       ...       ...       ...       ...       ...       ...
# 20995  1.194977 -2.978662 -4.481692 -3.105750 -0.622107 -0.578853  2.657076
# 20996  7.156865 -9.505980 -2.669331 -5.123208  4.149112 -0.378593  7.578786
# 20997 -5.132452 -5.161143 -2.741323 -7.561555 -1.135327 -9.401466  0.149034
# 20998 -6.405990 -2.165575 -4.548413 -5.225347 -3.212550 -5.804657 -2.842009
# 20999 -3.697226 -5.407853 -3.259724 -8.465958 -2.646412 -8.375465 -1.324651
#
#          labels
# 0          FEAR
# 1          FEAR
# 2          FEAR
# 3          FEAR
# 4          FEAR
# ...         ...
# 20995     ANGRY
# 20996     ANGRY
# 20997  SURPRISE
# 20998  SURPRISE
# 20999  SURPRISE
#
# [21000 rows x 21 columns]

# %%
X = Features.iloc[: ,:-1].values
Y = Features['labels'].values

# %%
# As this is a multiclass classification problem onehotencoding our Y.
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
# splitting data
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((15750, 20), (15750, 7), (5250, 20), (5250, 7))

# %% [markdown]
# ## Client 1 Data

# %%
client1 = pd.read_csv("/kaggle/input/subesco-features/features.csv")[:5251]

client1_X = client1.iloc[: ,:-1].values
client1_Y = client1['labels'].values

# As this is a multiclass classification problem onehotencoding our Y.
client1_encoder = OneHotEncoder()
client1_Y = client1_encoder.fit_transform(np.array(client1_Y).reshape(-1,1)).toarray()

# splitting data
client1_x_train, client1_x_test, client1_y_train, client1_y_test = train_test_split(client1_X, client1_Y, random_state=0, shuffle=True)
# 5249  SURPRISE
# 5250     ANGRY
#
# [5251 rows x 21 columns]

# %%
client2 = pd.read_csv("/kaggle/input/subesco-features/features.csv")[5251:5251+5251]

client2_X = client2.iloc[: ,:-1].values
client2_Y = client2['labels'].values

# As this is a multiclass classification problem onehotencoding our Y.
client2_encoder = OneHotEncoder()
client2_Y = client2_encoder.fit_transform(np.array(client2_Y).reshape(-1,1)).toarray()

# splitting data
client2_x_train, client2_x_test, client2_y_train, client2_y_test = train_test_split(client2_X, client2_Y, random_state=0, shuffle=True)
client2_x_train.shape, client2_y_train.shape, client2_x_test.shape, client2_y_test.shape

client2
# Out:
#                 0          1          2          3          4         5  \
# 5251   -96.446932  58.952119 -11.201502  17.527855  -0.034643  3.025175
# 5252  -175.240417  72.441910 -15.737305  18.658489  -5.158367  0.556253
# 5253  -105.513542  52.425194 -18.052237  20.589254  -8.066584 -1.580102
# 5254   -38.855673  35.726012 -13.078980  12.055435  -4.908257 -3.618030
# 5255  -155.885895  51.680653 -20.326433  20.003632 -12.194021 -1.777348
# ...           ...        ...        ...        ...        ...       ...
# 10497 -347.718719  66.897797  -0.329567   4.047008  -3.195995  0.351910
# 10498 -223.084400  44.298526   1.551004   1.211149  -1.404857 -1.424537
# 10499 -397.362823  68.660934  -2.909887   4.688513  -4.250721 -0.787711
# 10500 -189.813110  82.641991   6.053026  23.385021   4.664502  2.402582
# 10501 -139.839062  62.305327   8.215006  17.240265   5.354479 -0.656882
#
#                6         7          8         9  ...        11         12  \
# 5251   -9.665816 -0.109583 -10.566753 -2.750299  ... -0.575223  -6.556886
# 5252  -15.649349 -0.666911 -14.135413 -0.283467  ...  2.707812  -7.831130
# 5253  -10.010830  4.835215 -13.409306  2.630087  ...  6.542460  -8.030570
# 5254   -7.034560  0.226506  -9.511170 -1.720029  ...  1.634555  -3.950413
# 5255  -10.453744  3.493349 -15.340064  0.921567  ...  6.761473 -10.551084
# ...          ...       ...        ...       ...  ...       ...        ...
# 10497  -6.560800 -2.332381 -11.897405  4.241099  ... -0.762889  -7.005482
# 10498  -4.084514 -5.218085  -7.538543 -0.718616  ... -2.313818  -4.509688
# 10499  -8.447639 -5.223751 -13.269318  3.233104  ... -1.607624  -8.086882
# 10500  -8.307278  3.934511 -13.201906  1.793428  ... -0.209537 -10.208645
# 10501  -5.072312  0.116796  -8.850082 -2.300256  ... -4.015301  -7.289311
#
#              13        14        15        16         17         18  \
# 5251  -0.539905 -4.355602 -1.047951 -6.844130   1.309313  -4.294463
# 5252   0.880782 -7.808378 -1.131344 -8.292178   3.620916  -5.855865
# 5253   4.419231 -5.132985 -1.224084 -0.185453   9.111850   2.629003
# 5254   0.831072 -2.228564 -3.759214  2.276872   5.819085   5.797076
# 5255   5.580077 -7.884958  2.045137  3.504383  11.789952   6.389785
# ...         ...       ...       ...       ...        ...        ...
# 10497 -1.591897 -3.391819 -2.170052 -3.725774   0.020747  -6.701715
# 10498 -3.253467 -2.276046 -2.778382 -2.091528  -1.428513  -3.810903
# 10499 -0.618059 -5.762129 -3.063206 -4.786630  -2.750978  -7.525505
# 10500 -1.920654 -5.988425 -6.981678 -9.150655  -1.020934 -10.464436
# 10501 -4.399556 -4.165287 -7.535638 -6.919645  -3.257334  -7.069517
#
#               19    labels
# 5251    0.712111     ANGRY
# 5252    3.020264     ANGRY
# 5253   16.271971     ANGRY
# 5254   11.881790     ANGRY
# 5255   16.005247     ANGRY
# ...          ...       ...
# 10497   0.165465  SURPRISE
# 10498  -1.881142  SURPRISE
# 10499  -0.228424  SURPRISE
# 10500  -2.747308  SURPRISE
# 10501  -4.717926  SURPRISE
#
# [5251 rows x 21 columns]

# %%
client3 = pd.read_csv("/kaggle/input/subesco-features/features.csv")[5251+5251:5251+5251+5251]

client3_X = client3.iloc[: ,:-1].values
client3_Y = client3['labels'].values

# As this is a multiclass classification problem onehotencoding our Y.
client3_encoder = OneHotEncoder()
client3_Y = client3_encoder.fit_transform(np.array(client3_Y).reshape(-1,1)).toarray()

# splitting data
client3_x_train, client3_x_test, client3_y_train, client3_y_test = train_test_split(client3_X, client3_Y, random_state=0, shuffle=True)
client3_x_train.shape, client3_y_train.shape, client3_x_test.shape, client3_y_test.shape

client3
# Out:
#                 0          1          2          3          4          5  \
# 10502 -230.701569  85.508652   3.299722  20.547522   2.356920   3.094531
# 10503 -146.071823  56.854362 -15.752464   9.294368 -10.581990   2.019128
# 10504  -56.738456  39.305711  -9.197306   4.473067  -5.636937  -2.451784
# 10505 -202.044617  56.560516 -17.852388   8.192094 -11.789543   0.982954
# 10506 -105.698975  67.280602  -9.305779  19.977934  -5.116921  -1.739243
# ...           ...        ...        ...        ...        ...        ...
# 15748 -197.897982  66.467972  25.966430  26.543431  11.226605   3.290638
# 15749 -315.905914  97.718651  21.947592  39.054565   6.397556   6.422866
# 15750 -174.506653  53.805233 -18.541727  12.615558 -14.337981  -8.688640
# 15751  -99.588365  33.374921  -9.404595   5.066050  -9.034571 -10.771791
# 15752 -220.168716  53.901443 -19.143129   9.162455 -19.014633  -8.624665
#
#                6         7          8         9  ...        11         12  \
# 10502  -8.517960  1.339766 -14.322568  0.804560  ... -0.744439 -11.471883
# 10503 -11.964455 -0.879675 -11.475738  5.880419  ...  3.325857  -9.984863
# 10504  -7.491794 -4.165961  -6.885054  2.651277  ... -1.101043  -5.065498
# 10505 -12.190911 -0.452675 -11.325714  6.858427  ...  2.253631 -12.548748
# 10506  -9.270170 -3.796736 -22.967772 -0.909911  ...  1.773396 -11.832561
# ...          ...       ...        ...       ...  ...       ...        ...
# 15748  -2.695787  0.204719  -3.505397 -5.619461  ... -1.957467  -5.271568
# 15749  -6.883896  2.494805  -8.266067 -4.749612  ...  2.015421  -9.516028
# 15750  -8.750062 -3.698563 -20.919596 -1.138144  ...  1.320388  -8.536187
# 15751  -5.901810 -5.763838 -15.131991 -5.808634  ... -2.464102  -5.328121
# 15752  -9.025378 -7.024032 -22.749878 -1.943747  ...  1.368640  -9.134007
#
#              13         14         15        16         17        18  \
# 10502  0.297951  -7.818252  -7.739704 -7.948488  -3.244009 -9.635745
# 10503 -3.309105 -10.009208  -1.948913 -8.657032   0.683340 -3.223425
# 10504 -6.163092  -6.860609  -5.063777 -5.324733  -2.353022  0.637055
# 10505 -2.929937  -9.961913  -0.140418 -8.815154   2.292598 -0.899928
# 10506  3.381842  -6.034243   4.635303  0.962453   8.267925 -1.410582
# ...         ...        ...        ...       ...        ...       ...
# 15748 -4.821481  -1.777628  -4.037737 -3.162661  -1.917357 -3.214414
# 15749 -0.995314  -2.058545  -5.121648 -4.454018  -1.449538 -6.653224
# 15750  1.256901  -7.043962   5.447093  8.211259  11.898779  2.984030
# 15751 -2.366017  -3.355072   2.896502  9.629173   8.124023  4.335621
# 15752  1.028665  -5.938792  12.098886  9.833618  10.800608  0.944237
#
#               19    labels
# 10502  -2.868759  SURPRISE
# 10503   9.507171  SURPRISE
# 10504   7.079628  SURPRISE
# 10505  11.637966  SURPRISE
# 10506   8.787042  SURPRISE
# ...          ...       ...
# 15748  -4.593687   NEUTRAL
# 15749  -3.873835   NEUTRAL
# 15750   5.267905  SURPRISE
# 15751   2.601403  SURPRISE
# 15752   1.497591  SURPRISE
#
# [5251 rows x 21 columns]

# %%
client4 = pd.read_csv("/kaggle/input/subesco-features/features.csv")[5251+5251+5251:5251+5251+5251+5251]

client4_X = client4.iloc[: ,:-1].values
client4_Y = client4['labels'].values

# As this is a multiclass classification problem onehotencoding our Y.
client4_encoder = OneHotEncoder()
client4_Y = client4_encoder.fit_transform(np.array(client4_Y).reshape(-1,1)).toarray()

# splitting data
client4_x_train, client4_x_test, client4_y_train, client4_y_test = train_test_split(client4_X, client4_Y, random_state=0, shuffle=True)
client4_x_train.shape, client4_y_train.shape, client4_x_test.shape, client4_y_test.shape

client4
# Out:
#                 0          1          2          3          4          5  \
# 15753 -314.668091  64.371078   7.132384  37.017460  18.596500  -6.529037
# 15754 -148.749003  24.467857   0.083345  15.666520   8.278915  -7.330945
# 15755 -349.854065  56.961071   0.865716  36.187523  12.707027 -12.814258
# 15756 -368.404297  53.999374   1.046352  15.590069   3.335876  -1.686611
# 15757 -158.750034  29.027306   6.407988   5.258316   4.182782  -0.911810
# ...           ...        ...        ...        ...        ...        ...
# 20995 -147.915032  35.312209  -6.290578   8.826300  -1.185107  -1.087470
# 20996 -279.854645  62.046352 -11.338968  15.105037  -6.672193   1.285805
# 20997 -183.201843  54.706821   3.693384  16.859709   0.532207   1.059522
# 20998 -100.381958  41.417833   8.197202  10.640884   2.796847  -1.045510
# 20999 -236.028137  55.347431   3.616604  16.496374  -0.726685  -0.580750
#
#                6         7          8         9  ...        11         12  \
# 15753 -16.726259 -2.345631 -12.539331 -1.298656  ... -1.318820  -2.403266
# 15754  -8.801352 -4.300032  -6.985714 -4.975587  ... -2.992230  -2.100719
# 15755 -18.348564 -4.850488 -13.799018 -1.994595  ...  0.172991  -3.265655
# 15756  -7.309099  1.596822  -6.636775  1.501090  ...  5.210227  -6.591059
# 15757  -4.475865 -2.932713  -3.231777 -1.325502  ...  0.642064  -2.616520
# ...          ...       ...        ...       ...  ...       ...        ...
# 20995  -7.562760 -0.137674  -1.489993  1.201304  ... -2.170095  -6.827629
# 20996 -12.235703  4.287932  -3.291110  4.699277  ...  0.055803  -9.658722
# 20997 -11.227297 -0.826561 -12.857935  0.725828  ... -1.448650  -9.543724
# 20998  -6.037356 -4.348273  -8.323692 -3.680360  ... -4.914932  -5.864114
# 20999 -12.464178 -2.115311 -13.284043 -0.442617  ... -0.915420 -12.053455
#
#              13        14        15        16        17        18        19  \
# 15753 -1.028725 -6.771652 -1.903546 -9.021447 -1.107761 -6.602578 -1.855388
# 15754 -3.020085 -3.365295 -2.817974 -4.721818 -2.931566 -3.378900 -3.640154
# 15755 -2.232108 -7.700751 -3.401174 -8.216926 -0.354543 -6.549814  0.437165
# 15756 -1.106053 -0.027923  1.308261 -4.239492 -2.998619 -5.040117  1.910766
# 15757 -3.032190  0.524327  0.736210 -2.554542 -3.777683 -2.068887 -1.109672
# ...         ...       ...       ...       ...       ...       ...       ...
# 20995  1.194977 -2.978662 -4.481692 -3.105750 -0.622107 -0.578853  2.657076
# 20996  7.156865 -9.505980 -2.669331 -5.123208  4.149112 -0.378593  7.578786
# 20997 -5.132452 -5.161143 -2.741323 -7.561555 -1.135327 -9.401466  0.149034
# 20998 -6.405990 -2.165575 -4.548413 -5.225347 -3.212550 -5.804657 -2.842009
# 20999 -3.697226 -5.407853 -3.259724 -8.465958 -2.646412 -8.375465 -1.324651
#
#          labels
# 15753     HAPPY
# 15754     HAPPY
# 15755     HAPPY
# 15756   NEUTRAL
# 15757   NEUTRAL
# ...         ...
# 20995     ANGRY
# 20996     ANGRY
# 20997  SURPRISE
# 20998  SURPRISE
# 20999  SURPRISE
#
# [5247 rows x 21 columns]

# %% [markdown]
# # Train Test Split

# %%
x_traincnn =np.expand_dims(x_train, axis=2)
x_testcnn= np.expand_dims(x_test, axis=2)
x_traincnn.shape, y_train.shape, x_testcnn.shape, y_test.shape
# Out:
# ((15750, 20, 1), (15750, 7), (5250, 20, 1), (5250, 7))

# %% [markdown]
# # Client 1 Local Train Test Split

# %%
client1_x_traincnn =np.expand_dims(client1_x_train, axis=2)
client1_x_testcnn= np.expand_dims(client1_x_test, axis=2)
client1_x_traincnn.shape, client1_y_train.shape, client1_x_testcnn.shape, client1_y_test.shape
# Out:
# ((3938, 20, 1), (3938, 7), (1313, 20, 1), (1313, 7))

# %% [markdown]
# # Client 2 Local Train Test Split

# %%
client2_x_traincnn =np.expand_dims(client2_x_train, axis=2)
client2_x_testcnn= np.expand_dims(client2_x_test, axis=2)
client2_x_traincnn.shape, client2_y_train.shape, client2_x_testcnn.shape, client2_y_test.shape
# Out:
# ((3938, 20, 1), (3938, 7), (1313, 20, 1), (1313, 7))

# %% [markdown]
# # Client 3 Local Train Test Split

# %%
client3_x_traincnn =np.expand_dims(client3_x_train, axis=2)
client3_x_testcnn= np.expand_dims(client3_x_test, axis=2)
client3_x_traincnn.shape, client3_y_train.shape, client3_x_testcnn.shape, client3_y_test.shape
# Out:
# ((3938, 20, 1), (3938, 7), (1313, 20, 1), (1313, 7))

# %% [markdown]
# # Client 4 Local Train Test Split

# %%
client4_x_traincnn =np.expand_dims(client4_x_train, axis=2)
client4_x_testcnn= np.expand_dims(client4_x_test, axis=2)
client4_x_traincnn.shape, client4_y_train.shape, client4_x_testcnn.shape, client4_y_test.shape
# Out:
# ((3935, 20, 1), (3935, 7), (1312, 20, 1), (1312, 7))

# %% [markdown]
# # Client 1 Model

# %%
model1 = Sequential()
model1.add(Conv1D(2048, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model1.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model1.add(BatchNormalization())

model1.add(Conv1D(1024, kernel_size=5, strides=1, padding='same', activation='relu'))
model1.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model1.add(BatchNormalization())

model1.add(Conv1D(512, kernel_size=5, strides=1, padding='same', activation='relu'))
model1.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model1.add(BatchNormalization())

model1.add(LSTM(256, return_sequences=True))

model1.add(LSTM(128))

model1.add(Dense(128, activation='relu'))
model1.add(Dropout(0.5))

model1.add(Dense(64, activation='relu'))
model1.add(Dropout(0.5))

model1.add(Dense(32, activation='relu'))
model1.add(Dropout(0.5))

model1.add(Dense(16, activation='relu'))
model1.add(Dropout(0.2))

model1.add(Dense(8, activation='relu'))
model1.add(Dropout(0.2))

model1.add(Dense(7, activation='softmax'))

optimiser1 = tf.keras.optimizers.Adam(learning_rate=0.0001)
model1.compile(optimizer=optimiser1,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 20, 2048)          12288
#
#  max_pooling1d (MaxPooling1  (None, 10, 2048)          0
#  D)
#
#  batch_normalization (Batch  (None, 10, 2048)          8192
#  Normalization)
#
#  conv1d_1 (Conv1D)           (None, 10, 1024)          10486784
#
#  max_pooling1d_1 (MaxPoolin  (None, 5, 1024)           0
#  g1D)
#
#  batch_normalization_1 (Bat  (None, 5, 1024)           4096
#  chNormalization)
#
#  conv1d_2 (Conv1D)           (None, 5, 512)            2621952
#
#  max_pooling1d_2 (MaxPoolin  (None, 3, 512)            0
#  g1D)
#
#  batch_normalization_2 (Bat  (None, 3, 512)            2048
#  chNormalization)
#
#  lstm (LSTM)                 (None, 3, 256)            787456
#
#  lstm_1 (LSTM)               (None, 128)               197120
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 16)                528
#
#  dropout_3 (Dropout)         (None, 16)                0
#
#  dense_4 (Dense)             (None, 8)                 136
#
#  dropout_4 (Dropout)         (None, 8)                 0
#
#  dense_5 (Dense)             (None, 7)                 63
#
# =================================================================
# Total params: 14147511 (53.97 MB)
# Trainable params: 14140343 (53.94 MB)
# Non-trainable params: 7168 (28.00 KB)
# _________________________________________________________________

# %%
history1 = model1.fit(client1_x_traincnn, client1_y_train, batch_size=64, epochs=100, validation_data=(client1_x_testcnn, client1_y_test))
# Out:
# Epoch 1/100
# 62/62 [==============================] - 28s 64ms/step - loss: 1.9426 - accuracy: 0.1562 - val_loss: 1.9383 - val_accuracy: 0.1950
# Epoch 2/100
# 62/62 [==============================] - 2s 32ms/step - loss: 1.9407 - accuracy: 0.1605 - val_loss: 1.9316 - val_accuracy: 0.2483
# Epoch 3/100
# 62/62 [==============================] - 2s 31ms/step - loss: 1.9303 - accuracy: 0.1640 - val_loss: 1.9254 - val_accuracy: 0.2704
# Epoch 4/100
# 62/62 [==============================] - 2s 31ms/step - loss: 1.9230 - accuracy: 0.1811 - val_loss: 1.9043 - val_accuracy: 0.2841
# Epoch 5/100
# 62/62 [==============================] - 2s 31ms/step - loss: 1.9099 - accuracy: 0.1910 - val_loss: 1.9205 - val_accuracy: 0.2186
# Epoch 6/100
# 62/62 [==============================] - 2s 32ms/step - loss: 1
100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.9373 - accuracy: 0.6392 - val_loss: 1.1638 - val_accuracy: 0.6207
# Epoch 97/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.8905 - accuracy: 0.6460 - val_loss: 1.3029 - val_accuracy: 0.6497
# Epoch 98/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.8509 - accuracy: 0.6513 - val_loss: 1.1487 - val_accuracy: 0.6710
# Epoch 99/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.9146 - accuracy: 0.6475 - val_loss: 1.1939 - val_accuracy: 0.6740
# Epoch 100/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.8815 - accuracy: 0.6521 - val_loss: 1.2104 - val_accuracy: 0.6306

# %%
print("Accuracy of our model on test data : " , model1.evaluate(client1_x_testcnn,client1_y_test)[1]*100 , "%")
# Out:
# 42/42 [==============================] - 1s 10ms/step - loss: 1.2104 - accuracy: 0.6306
# Accuracy of our model on test data :  63.06169033050537 %

# %% [markdown]
# # Client 2 Model

# %%
model2 = Sequential()
model2.add(Conv1D(2048, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model2.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model2.add(BatchNormalization())

model2.add(Conv1D(1024, kernel_size=5, strides=1, padding='same', activation='relu'))
model2.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model2.add(BatchNormalization())

model2.add(Conv1D(512, kernel_size=5, strides=1, padding='same', activation='relu'))
model2.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model2.add(BatchNormalization())

model2.add(LSTM(256, return_sequences=True))

model2.add(LSTM(128))

model2.add(Dense(128, activation='relu'))
model2.add(Dropout(0.5))

model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.5))

model2.add(Dense(32, activation='relu'))
model2.add(Dropout(0.5))

model2.add(Dense(16, activation='relu'))
model2.add(Dropout(0.2))

model2.add(Dense(8, activation='relu'))
model2.add(Dropout(0.2))

model2.add(Dense(7, activation='softmax'))

optimiser2 = tf.keras.optimizers.Adam(learning_rate=0.0001)
model2.compile(optimizer=optimiser2,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 20, 2048)          12288
#
#  max_pooling1d_3 (MaxPoolin  (None, 10, 2048)          0
#  g1D)
#
#  batch_normalization_3 (Bat  (None, 10, 2048)          8192
#  chNormalization)
#
#  conv1d_4 (Conv1D)           (None, 10, 1024)          10486784
#
#  max_pooling1d_4 (MaxPoolin  (None, 5, 1024)           0
#  g1D)
#
#  batch_normalization_4 (Bat  (None, 5, 1024)           4096
#  chNormalization)
#
#  conv1d_5 (Conv1D)           (None, 5, 512)            2621952
#
#  max_pooling1d_5 (MaxPoolin  (None, 3, 512)            0
#  g1D)
#
#  batch_normalization_5 (Bat  (None, 3, 512)            2048
#  chNormalization)
#
#  lstm_2 (LSTM)               (None, 3, 256)            787456
#
#  lstm_3 (LSTM)               (None, 128)               197120
#
#  dense_6 (Dense)             (None, 128)               16512
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 32)                2080
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_9 (Dense)             (None, 16)                528
#
#  dropout_8 (Dropout)         (None, 16)                0
#
#  dense_10 (Dense)            (None, 8)                 136
#
#  dropout_9 (Dropout)         (None, 8)                 0
#
#  dense_11 (Dense)            (None, 7)                 63
#
# =================================================================
# Total params: 14147511 (53.97 MB)
# Trainable params: 14140343 (53.94 MB)
# Non-trainable params: 7168 (28.00 KB)
# _________________________________________________________________

# %%
history2 = model2.fit(client2_x_traincnn, client2_y_train, batch_size=64, epochs=100, validation_data=(client2_x_testcnn, client2_y_test))
# Out:
# Epoch 1/100
# 62/62 [==============================] - 11s 50ms/step - loss: 1.9438 - accuracy: 0.1620 - val_loss: 1.9395 - val_accuracy: 0.1714
# Epoch 2/100
# 62/62 [==============================] - 2s 35ms/step - loss: 1.9300 - accuracy: 0.1767 - val_loss: 1.9185 - val_accuracy: 0.1912
# Epoch 3/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.
100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.9752 - accuracy: 0.6384 - val_loss: 1.2211 - val_accuracy: 0.6474
# Epoch 95/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.9612 - accuracy: 0.6384 - val_loss: 1.1370 - val_accuracy: 0.6778
# Epoch 96/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.9710 - accuracy: 0.6356 - val_loss: 1.1322 - val_accuracy: 0.6725
# Epoch 97/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.9458 - accuracy: 0.6595 - val_loss: 1.1796 - val_accuracy: 0.6855
# Epoch 98/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.9440 - accuracy: 0.6579 - val_loss: 1.1342 - val_accuracy: 0.6954
# Epoch 99/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.9362 - accuracy: 0.6541 - val_loss: 1.1067 - val_accuracy: 0.6877
# Epoch 100/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.9240 - accuracy: 0.6679 - val_loss: 1.2104 - val_accuracy: 0.7083

# %%
print("Accuracy of our model on test data : " , model2.evaluate(client2_x_testcnn,client2_y_test)[1]*100 , "%")
# Out:
# 42/42 [==============================] - 0s 7ms/step - loss: 1.2104 - accuracy: 0.7083
# Accuracy of our model on test data :  70.83016037940979 %

# %% [markdown]
# # Client 3 Model

# %%
model3 = Sequential()
model3.add(Conv1D(2048, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model3.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model3.add(BatchNormalization())

model3.add(Conv1D(1024, kernel_size=5, strides=1, padding='same', activation='relu'))
model3.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model3.add(BatchNormalization())

model3.add(Conv1D(512, kernel_size=5, strides=1, padding='same', activation='relu'))
model3.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model3.add(BatchNormalization())

model3.add(LSTM(256, return_sequences=True))

model3.add(LSTM(128))

model3.add(Dense(128, activation='relu'))
model3.add(Dropout(0.5))

model3.add(Dense(64, activation='relu'))
model3.add(Dropout(0.5))

model3.add(Dense(32, activation='relu'))
model3.add(Dropout(0.5))

model3.add(Dense(16, activation='relu'))
model3.add(Dropout(0.2))

model3.add(Dense(8, activation='relu'))
model3.add(Dropout(0.2))

model3.add(Dense(7, activation='softmax'))

optimiser3 = tf.keras.optimizers.Adam(learning_rate=0.0001)
model3.compile(optimizer=optimiser3,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (None, 20, 2048)          12288
#
#  max_pooling1d_6 (MaxPoolin  (None, 10, 2048)          0
#  g1D)
#
#  batch_normalization_6 (Bat  (None, 10, 2048)          8192
#  chNormalization)
#
#  conv1d_7 (Conv1D)           (None, 10, 1024)          10486784
#
#  max_pooling1d_7 (MaxPoolin  (None, 5, 1024)           0
#  g1D)
#
#  batch_normalization_7 (Bat  (None, 5, 1024)           4096
#  chNormalization)
#
#  conv1d_8 (Conv1D)           (None, 5, 512)            2621952
#
#  max_pooling1d_8 (MaxPoolin  (None, 3, 512)            0
#  g1D)
#
#  batch_normalization_8 (Bat  (None, 3, 512)            2048
#  chNormalization)
#
#  lstm_4 (LSTM)               (None, 3, 256)            787456
#
#  lstm_5 (LSTM)               (None, 128)               197120
#
#  dense_12 (Dense)            (None, 128)               16512
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_14 (Dense)            (None, 32)                2080
#
#  dropout_12 (Dropout)        (None, 32)                0
#
#  dense_15 (Dense)            (None, 16)                528
#
#  dropout_13 (Dropout)        (None, 16)                0
#
#  dense_16 (Dense)            (None, 8)                 136
#
#  dropout_14 (Dropout)        (None, 8)                 0
#
#  dense_17 (Dense)            (None, 7)                 63
#
# =================================================================
# Total params: 14147511 (53.97 MB)
# Trainable params: 14140343 (53.94 MB)
# Non-trainable params: 7168 (28.00 KB)
# _________________________________________________________________

# %%
history3 = model3.fit(client3_x_traincnn, client3_y_train, batch_size=64, epochs=100, validation_data=(client3_x_testcnn, client3_y_test))
# Out:
# Epoch 1/100
# 62/62 [==============================] - 12s 51ms/step - loss: 1.9444 - accuracy: 0.1524 - val_loss: 1.9434 - val_accuracy: 0.1706
# Epoch 2/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.9366 - accuracy: 0.1546 - val_loss: 1.9417 - val_accuracy: 0.1759
# Epoch 3/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.9277 - accuracy: 0.1536 - val_loss: 1.9385 - val_accuracy: 0.1592
# Epoch 4/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.9191 - accuracy: 0.1623 - val_loss: 1.9289 - val_accuracy: 0.1744
# Epoch 5/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.9116 - accuracy: 0.1694 - val_loss: 1.9183 - val_accuracy: 0.2072
# Epoch 6/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.9033 - accuracy: 0.1734 - val_loss: 1.9235 - val_accuracy: 0.1896
# Epoch 7/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.9002 - accuracy: 0.1821 - val_loss: 1.9202 - val_accuracy: 0.2254
# Epoch 8/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8953 - accuracy: 0.1897 - val_loss: 1.8804 - val_accuracy: 0.2216
# Epoch 9/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8933 - accuracy: 0.1877 - val_loss: 1.9219 - val_accuracy: 0.2094
# Epoch 10/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8919 - accuracy: 0.1927 - val_loss: 1.9005 - val_accuracy: 0.2079
# Epoch 11/100
# 62/62 [==============================] - 2s 34ms/step - loss: 1.8771 - accuracy: 0.1927 - val_loss: 1.8778 - val_accuracy: 0.2209
# Epoch 12/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8805 - accuracy: 0.1981 - val_loss: 1.8664 - val_accuracy: 0.2262
# Epoch 13/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8708 - accuracy: 0.2080 - val_loss: 1.8767 - val_accuracy: 0.2155
# Epoch 14/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8828 - accuracy: 0.1971 - val_loss: 1.8924 - val_accuracy: 0.2087
# Epoch 15/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8710 - accuracy: 0.1907 - val_loss: 1.8588 - val_accuracy: 0.2285
# Epoch 16/100
# 62/62 [==============================] - 2s 34ms/step - loss: 1.8601 - accuracy: 0.2039 - val_loss: 1.8419 - val_accuracy: 0.2011
# Epoch 17/100
# 62/62 [==============================] - 2s 34ms/step - loss: 1.8598 - accuracy: 0.2194 - val_loss: 1.8679 - val_accuracy: 0.2087
# Epoch 18/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8517 - accuracy: 0.2098 - val_loss: 1.8350 - val_accuracy: 0.2338
# Epoch 19/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8485 - accuracy: 0.2120 - val_loss: 1.8929 - val_accuracy: 0.2064
# Epoch 20/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8511 - accuracy: 0.2164 - val_loss: 1.8552 - val_accuracy: 0.2140
# Epoch 21/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8367 - accuracy: 0.2255 - val_loss: 1.8793 - val_accuracy: 0.2072
# Epoch 22/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8367 - accuracy: 0.2176 - val_loss: 1.8836 - val_accuracy: 0.2087
# Epoch 23/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8339 - accuracy: 0.2250 - val_loss: 1.8051 - val_accuracy: 0.2323
# Epoch 24/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8235 - accuracy: 0.2308 - val_loss: 1.8347 - val_accuracy: 0.2407
# Epoch 25/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8241 - accuracy: 0.2384 - val_loss: 1.8122 - val_accuracy: 0.2506
# Epoch 26/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8225 - accuracy: 0.2316 - val_loss: 1.8239 - val_accuracy: 0.2384
# Epoch 27/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8122 - accuracy: 0.2344 - val_loss: 1.8356 - val_accuracy: 0.2300
# Epoch 28/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8067 - accuracy: 0.2283 - val_loss: 1.8000 - val_accuracy: 0.2353
# Epoch 29/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8005 - accuracy: 0.2336 - val_loss: 1.8158 - val_accuracy: 0.2346
# Epoch 30/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.
100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.2406 - accuracy: 0.5089 - val_loss: 1.4837 - val_accuracy: 0.5248
# Epoch 92/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.2863 - accuracy: 0.4825 - val_loss: 1.5071 - val_accuracy: 0.5369
# Epoch 93/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.3006 - accuracy: 0.4820 - val_loss: 1.4687 - val_accuracy: 0.5133
# Epoch 94/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.2681 - accuracy: 0.4929 - val_loss: 1.4480 - val_accuracy: 0.5400
# Epoch 95/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.2331 - accuracy: 0.5053 - val_loss: 1.4701 - val_accuracy: 0.5209
# Epoch 96/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.2095 - accuracy: 0.5165 - val_loss: 1.5342 - val_accuracy: 0.5468
# Epoch 97/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.2092 - accuracy: 0.5137 - val_loss: 1.5407 - val_accuracy: 0.5446
# Epoch 98/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.2385 - accuracy: 0.5018 - val_loss: 1.5660 - val_accuracy: 0.5103
# Epoch 99/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.2289 - accuracy: 0.5142 - val_loss: 1.4556 - val_accuracy: 0.5362
# Epoch 100/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.1914 - accuracy: 0.5132 - val_loss: 1.4674 - val_accuracy: 0.5316

# %%
print("Accuracy of our model on test data : " , model3.evaluate(client3_x_testcnn,client3_y_test)[1]*100 , "%")
# Out:
# 42/42 [==============================] - 0s 11ms/step - loss: 1.4674 - accuracy: 0.5316
# Accuracy of our model on test data :  53.16070318222046 %

# %% [markdown]
# # Client 4 Model

# %%
model4 = Sequential()
model4.add(Conv1D(2048, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model4.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model4.add(BatchNormalization())

model4.add(Conv1D(1024, kernel_size=5, strides=1, padding='same', activation='relu'))
model4.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model4.add(BatchNormalization())

model4.add(Conv1D(512, kernel_size=5, strides=1, padding='same', activation='relu'))
model4.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model4.add(BatchNormalization())

model4.add(LSTM(256, return_sequences=True))

model4.add(LSTM(128))

model4.add(Dense(128, activation='relu'))
model4.add(Dropout(0.5))

model4.add(Dense(64, activation='relu'))
model4.add(Dropout(0.5))

model4.add(Dense(32, activation='relu'))
model4.add(Dropout(0.5))

model4.add(Dense(16, activation='relu'))
model4.add(Dropout(0.2))

model4.add(Dense(8, activation='relu'))
model4.add(Dropout(0.2))

model4.add(Dense(7, activation='softmax'))

optimiser4 = tf.keras.optimizers.Adam(learning_rate=0.0001)
model4.compile(optimizer=optimiser4,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

model4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_9 (Conv1D)           (None, 20, 2048)          12288
#
#  max_pooling1d_9 (MaxPoolin  (None, 10, 2048)          0
#  g1D)
#
#  batch_normalization_9 (Bat  (None, 10, 2048)          8192
#  chNormalization)
#
#  conv1d_10 (Conv1D)          (None, 10, 1024)          10486784
#
#  max_pooling1d_10 (MaxPooli  (None, 5, 1024)           0
#  ng1D)
#
#  batch_normalization_10 (Ba  (None, 5, 1024)           4096
#  tchNormalization)
#
#  conv1d_11 (Conv1D)          (None, 5, 512)            2621952
#
#  max_pooling1d_11 (MaxPooli  (None, 3, 512)            0
#  ng1D)
#
#  batch_normalization_11 (Ba  (None, 3, 512)            2048
#  tchNormalization)
#
#  lstm_6 (LSTM)               (None, 3, 256)            787456
#
#  lstm_7 (LSTM)               (None, 128)               197120
#
#  dense_18 (Dense)            (None, 128)               16512
#
#  dropout_15 (Dropout)        (None, 128)               0
#
#  dense_19 (Dense)            (None, 64)                8256
#
#  dropout_16 (Dropout)        (None, 64)                0
#
#  dense_20 (Dense)            (None, 32)                2080
#
#  dropout_17 (Dropout)        (None, 32)                0
#
#  dense_21 (Dense)            (None, 16)                528
#
#  dropout_18 (Dropout)        (None, 16)                0
#
#  dense_22 (Dense)            (None, 8)                 136
#
#  dropout_19 (Dropout)        (None, 8)                 0
#
#  dense_23 (Dense)            (None, 7)                 63
#
# =================================================================
# Total params: 14147511 (53.97 MB)
# Trainable params: 14140343 (53.94 MB)
# Non-trainable params: 7168 (28.00 KB)
# _________________________________________________________________

# %%
history4 = model4.fit(client4_x_traincnn, client4_y_train, batch_size=64, epochs=100, validation_data=(client4_x_testcnn, client4_y_test))
# Out:
# Epoch 1/100
# 62/62 [==============================] - 12s 58ms/step - loss: 1.9336 - accuracy: 0.1537 - val_loss: 1.9160 - val_accuracy: 0.1677
# Epoch 2/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.9093 - accuracy: 0.1700 - val_loss: 1.8851 - val_accuracy: 0.2035
# Epoch 3/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8834 - accuracy: 0.1886 - val_loss: 1.8700 - val_accuracy: 0.2462
# Epoch 4/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8738 - accuracy: 0.2025 - val_loss: 1.8391 - val_accuracy: 0.2165
# Epoch 5/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8646 - accuracy: 0.2147 - val_loss: 1.8267 - val_accuracy: 0.2668
# Epoch 6/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8463 - accuracy: 0.2353 - val_loss: 1.8323 - val_accuracy: 0.2721
# Epoch 7/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8441 - accuracy: 0.2442 - val_loss: 1.8066 - val_accuracy: 0.2797
# Epoch 8/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8290 - accuracy: 0.2546 - val_loss: 1.8112 - val_accuracy: 0.2805
# Epoch 9/100
# 62/62 [==============================] - 2s 34ms/step - loss: 1.8262 - accuracy: 0.2559 - val_loss: 1.7890 - val_accuracy: 0.2820
# Epoch 10/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8254 - accuracy: 0.2729 - val_loss: 1.7965 - val_accuracy: 0.2790
# Epoch 11/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.8014 - accuracy: 0.2778 - val_loss: 1.7526 - val_accuracy: 0.3026
# Epoch 12/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.7805 - accuracy: 0.2803 - val_loss: 1.7616 - val_accuracy: 0.2965
# Epoch 13/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.7685 - accuracy: 0.2856 - val_loss: 1.7362 - val_accuracy: 0.3125
# Epoch 14/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.7778 - accuracy: 0.2930 - val_loss: 1.7636 - val_accuracy: 0.2919
# Epoch 15/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.7448 - accuracy: 0.2981 - val_loss: 1.7413 - val_accuracy: 0.3049
# Epoch 16/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.7565 - accuracy: 0.2981 - val_loss: 1.7074 - val_accuracy: 0.3209
# Epoch 17/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.7448 - accuracy: 0.3067 - val_loss: 1.6969 - val_accuracy: 0.3148
# Epoch 18/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.7329 - accuracy: 0.3085 - val_loss: 1.7355 - val_accuracy: 0.2965
# Epoch 19/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.7297 - accuracy: 0.3123 - val_loss: 1.7746 - val_accuracy: 0.3011
# Epoch 20/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.7097 - accuracy: 0.3222 - val_loss: 1.6713 - val_accuracy: 0.3354
# Epoch 21/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.7109 - accuracy: 0.3151 - val_loss: 1.6920 - val_accuracy: 0.3415
# Epoch 22/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.6923 - accuracy: 0.3276 - val_loss: 1.6648 - val_accuracy: 0.3430
# Epoch 23/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.6817 - accuracy: 0.3243 - val_loss: 1.6570 - val_accuracy: 0.3316
# Epoch 24/100
# 62/62 [==============================] - 2s 34ms/step - loss: 1.6784 - accuracy: 0.3220 - val_loss: 1.6674 - val_accuracy: 0.3453
# Epoch 25/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.
100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.0028 - accuracy: 0.5919 - val_loss: 1.1303 - val_accuracy: 0.6250
# Epoch 87/100
# 62/62 [==============================] - 2s 34ms/step - loss: 1.0251 - accuracy: 0.6094 - val_loss: 1.0983 - val_accuracy: 0.5991
# Epoch 88/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.9822 - accuracy: 0.6074 - val_loss: 1.1673 - val_accuracy: 0.6349
# Epoch 89/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.9604 - accuracy: 0.6196 - val_loss: 1.0521 - val_accuracy: 0.6463
# Epoch 90/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.9587 - accuracy: 0.6168 - val_loss: 1.0348 - val_accuracy: 0.6662
# Epoch 91/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.9723 - accuracy: 0.6145 - val_loss: 1.1555 - val_accuracy: 0.6296
# Epoch 92/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.9491 - accuracy: 0.6226 - val_loss: 1.0192 - val_accuracy: 0.6639
# Epoch 93/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.9552 - accuracy: 0.6221 - val_loss: 1.2035 - val_accuracy: 0.6159
# Epoch 94/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.9959 - accuracy: 0.6028 - val_loss: 1.1976 - val_accuracy: 0.5884
# Epoch 95/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.0713 - accuracy: 0.5830 - val_loss: 1.1106 - val_accuracy: 0.6402
# Epoch 96/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.0198 - accuracy: 0.6038 - val_loss: 1.2463 - val_accuracy: 0.6311
# Epoch 97/100
# 62/62 [==============================] - 2s 33ms/step - loss: 1.0129 - accuracy: 0.6086 - val_loss: 1.0151 - val_accuracy: 0.6387
# Epoch 98/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.9118 - accuracy: 0.6358 - val_loss: 0.9951 - val_accuracy: 0.6692
# Epoch 99/100
# 62/62 [==============================] - 2s 33ms/step - loss: 0.9471 - accuracy: 0.6341 - val_loss: 1.0185 - val_accuracy: 0.6662
# Epoch 100/100
# 62/62 [==============================] - 2s 34ms/step - loss: 0.9295 - accuracy: 0.6272 - val_loss: 1.0366 - val_accuracy: 0.6128

# %%
print("Accuracy of our model on test data : " , model4.evaluate(client4_x_testcnn,client4_y_test)[1]*100 , "%")
# Out:
# 41/41 [==============================] - 0s 11ms/step - loss: 1.0366 - accuracy: 0.6128
# Accuracy of our model on test data :  61.28048896789551 %

# %%
model = Sequential()
model.add(Conv1D(2048, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model.add(BatchNormalization())

model.add(Conv1D(1024, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model.add(BatchNormalization())

model.add(Conv1D(512, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model.add(BatchNormalization())

model.add(LSTM(256, return_sequences=True))

model.add(LSTM(128))

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(16, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(8, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(7, activation='softmax'))

optimiser = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimiser,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_12 (Conv1D)          (None, 20, 2048)          12288
#
#  max_pooling1d_12 (MaxPooli  (None, 10, 2048)          0
#  ng1D)
#
#  batch_normalization_12 (Ba  (None, 10, 2048)          8192
#  tchNormalization)
#
#  conv1d_13 (Conv1D)          (None, 10, 1024)          10486784
#
#  max_pooling1d_13 (MaxPooli  (None, 5, 1024)           0
#  ng1D)
#
#  batch_normalization_13 (Ba  (None, 5, 1024)           4096
#  tchNormalization)
#
#  conv1d_14 (Conv1D)          (None, 5, 512)            2621952
#
#  max_pooling1d_14 (MaxPooli  (None, 3, 512)            0
#  ng1D)
#
#  batch_normalization_14 (Ba  (None, 3, 512)            2048
#  tchNormalization)
#
#  lstm_8 (LSTM)               (None, 3, 256)            787456
#
#  lstm_9 (LSTM)               (None, 128)               197120
#
#  dense_24 (Dense)            (None, 128)               16512
#
#  dropout_20 (Dropout)        (None, 128)               0
#
#  dense_25 (Dense)            (None, 64)                8256
#
#  dropout_21 (Dropout)        (None, 64)                0
#
#  dense_26 (Dense)            (None, 32)                2080
#
#  dropout_22 (Dropout)        (None, 32)                0
#
#  dense_27 (Dense)            (None, 16)                528
#
#  dropout_23 (Dropout)        (None, 16)                0
#
#  dense_28 (Dense)            (None, 8)                 136
#
#  dropout_24 (Dropout)        (None, 8)                 0
#
#  dense_29 (Dense)            (None, 7)                 63
#
# =================================================================
# Total params: 14147511 (53.97 MB)
# Trainable params: 14140343 (53.94 MB)
# Non-trainable params: 7168 (28.00 KB)
# _________________________________________________________________

# %% [markdown]
# # Global Model

# %%
# Initialize the global model with model2 weights
model_weights = model2.get_weights()
model.set_weights(model_weights)

# Compile the global model with the desired optimizer and loss
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_testcnn,y_test)[1]*100 , "%")
# Out:
# 165/165 [==============================] - 3s 9ms/step - loss: 1.9915 - accuracy: 0.6206
# Accuracy of our model on test data :  62.057143449783325 %

# %%
accuracy1 = model1.evaluate(client1_x_testcnn,client1_y_test)
accuracy2 = model2.evaluate(client2_x_testcnn,client2_y_test)
accuracy3 = model3.evaluate(client3_x_testcnn,client3_y_test)
accuracy4 = model4.evaluate(client4_x_testcnn,client4_y_test)
# Out:
# 42/42 [==============================] - 0s 10ms/step - loss: 1.2104 - accuracy: 0.6306
# 42/42 [==============================] - 0s 7ms/step - loss: 1.2104 - accuracy: 0.7083
# 42/42 [==============================] - 0s 8ms/step - loss: 1.4674 - accuracy: 0.5316
# 41/41 [==============================] - 0s 7ms/step - loss: 1.0366 - accuracy: 0.6128

# %%
history = model.fit(x_traincnn, y_train, batch_size=64, epochs=50, validation_data=(x_testcnn, y_test))
# Out:
# Epoch 1/50
# 247/247 [==============================] - 17s 34ms/step - loss: 1.7697 - accuracy: 0.2570 - val_loss: 1.6469 - val_accuracy: 0.3215
# Epoch 2/50
# 247/247 [==============================] - 8s 33ms/step - loss: 1.6568 - accuracy: 0.3137 - val_loss: 1.6032 - val_accuracy: 0.3202
# Epoch 3/50
# 247/247 [==============================] - 8s 33ms/step - loss: 1.5812 - accuracy: 0.3517 - val_loss: 1.5053 - val_accuracy: 0.3874
# Epoch 4/50
# 247/247 [==============================] - 8s 33ms/step - loss: 1.5037 - accuracy: 0.3840 - val_loss: 1.5104 - val_accuracy: 0.3627
# Epoch 5/50
# 247/247 [==============================] - 8s 33ms/step - loss: 1.4574 - accuracy: 0.4082 - val_loss: 1.3770 - val_accuracy: 0.4406
# Epoch 6/50
# 247/247 [==============================] - 8s 33ms/step - loss: 1.4256 - accuracy: 0.4292 - val_loss: 1.3052 - val_accuracy: 0.4830
# Epoch 7/50
# 247/247 [==============================] - 8s 33ms/step - loss: 1.3769 - accuracy: 0.4564 - val_loss: 1.3359 - val_accuracy: 0.4684
# Epoch 8/50
# 247/247 [==============================] - 8s 33ms/step - loss: 1.3333 - accuracy: 0.4750 - val_loss: 1.4336 - val_accuracy: 0.4537
# Epoch 9/50
# 247/247 [==============================] - 8s 33ms/step - loss: 1.2799 - accuracy: 0.4964 - val_loss: 1.2250 - val_accuracy: 0.5322
# Epoch 10/50
# 247/247 [==============================] - 8s 33ms/step - loss: 1.2339 - accuracy: 0.5218 - val_loss: 1.1794 - val_accuracy: 0.5790
# Epoch 11/50
# 247/247 [==============================] - 8s 33ms/step - loss: 1.2343 - accuracy: 0.5301 - val_loss: 1.1672 - val_accuracy: 0.5634
# Epoch 12/50
# 247/247 [==============================] - 8s 33ms/step - loss: 1.1621 - accuracy: 0.5624 - val_loss: 1.0551 - val_accuracy: 0.6112
# Epoch 13/50
# 247/247 [==============================] - 8s 33ms/step - loss: 1
50
# 247/247 [==============================] - 8s 33ms/step - loss: 0.5211 - accuracy: 0.8432 - val_loss: 0.7381 - val_accuracy: 0.7832
# Epoch 44/50
# 247/247 [==============================] - 8s 33ms/step - loss: 0.4890 - accuracy: 0.8530 - val_loss: 0.7484 - val_accuracy: 0.8208
# Epoch 45/50
# 247/247 [==============================] - 8s 33ms/step - loss: 0.4606 - accuracy: 0.8618 - val_loss: 0.7621 - val_accuracy: 0.8350
# Epoch 46/50
# 247/247 [==============================] - 8s 33ms/step - loss: 0.4758 - accuracy: 0.8554 - val_loss: 0.8938 - val_accuracy: 0.8284
# Epoch 47/50
# 247/247 [==============================] - 8s 33ms/step - loss: 0.4659 - accuracy: 0.8667 - val_loss: 0.9142 - val_accuracy: 0.7943
# Epoch 48/50
# 247/247 [==============================] - 8s 33ms/step - loss: 0.5554 - accuracy: 0.8306 - val_loss: 0.9445 - val_accuracy: 0.8072
# Epoch 49/50
# 247/247 [==============================] - 8s 33ms/step - loss: 0.4706 - accuracy: 0.8603 - val_loss: 0.8449 - val_accuracy: 0.8227
# Epoch 50/50
# 247/247 [==============================] - 8s 33ms/step - loss: 0.4707 - accuracy: 0.8599 - val_loss: 0.9414 - val_accuracy: 0.8030

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_testcnn,y_test)[1]*100 , "%")
# Out:
# 165/165 [==============================] - 1s 8ms/step - loss: 0.9414 - accuracy: 0.8030
# Accuracy of our model on test data :  80.30475974082947 %

# %%
training_plot(history=history1, epoch=100, plot_name="Client Model 1")
training_plot(history=history2, epoch=100, plot_name="Client Model 2")
training_plot(history=history3, epoch=100, plot_name="Client Model 3")
training_plot(history=history4, epoch=100, plot_name="Client Model 4")
training_plot(history=history, epoch=50, plot_name="Global Model")

# %%
pred_test = model.predict(x_testcnn)
y_pred = encoder.inverse_transform(pred_test)
y_test = encoder.inverse_transform(y_test)

df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.head(100)
# Out:
# 165/165 [==============================] - 2s 6ms/step
#    Predicted Labels Actual Labels
# 0           DISGUST       DISGUST
# 1             ANGRY         ANGRY
# 2               SAD       NEUTRAL
# 3           NEUTRAL       NEUTRAL
# 4             ANGRY         ANGRY
# ..              ...           ...
# 95            HAPPY         HAPPY
# 96          DISGUST         ANGRY
# 97          DISGUST       DISGUST
# 98            HAPPY         HAPPY
# 99            HAPPY         HAPPY
#
# [100 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
# model_name = 'SUBESCCO_Sequential.h5'
# save_dir = os.path.join(os.getcwd(), 'saved_models')
# # Save model and weights
# if not os.path.isdir(save_dir):
#     os.makedirs(save_dir)
# model_path = os.path.join(save_dir, model_name)
# model.save(model_path)
# print('Saved trained model at %s ' % model_path)

# %%
# import json
# model_json = model.to_json()
# with open("model.json", "w") as json_file:
#     json_file.write(model_json)

# %%
# from keras.models import model_from_json
# json_file = open('model.json', 'r')
# loaded_model_json = json_file.read()
# json_file.close()
# loaded_model = model_from_json(loaded_model_json)
# # load weights into new model
# loaded_model.load_weights("/kaggle/working/saved_models/SUBESCCO_Sequential.h5")
# print("Loaded model from disk")

# %% [markdown]
# # Test Custom Audio

# %%
# data, sampling_rate = librosa.load('/kaggle/input/subescobangla-speech-emotion-dataset/SUBESCO/F_01_OISHI_S_10_ANGRY_4.wav')

# %%
# sample = "/kaggle/input/subescobangla-speech-emotion-dataset/SUBESCO/F_01_OISHI_S_10_ANGRY_4.wav"
# feature = get_feat(sample, sampling_rate)
# test =np.expand_dims(feature, axis=2)
# livepreds = model.predict(test)
# livepredictions = (encoder.inverse_transform((livepreds)))
# livepredictions
